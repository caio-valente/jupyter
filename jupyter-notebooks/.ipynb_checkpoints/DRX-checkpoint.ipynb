# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
from plotly.subplots import make_subplots

import pandas as pd
pd.options.plotting.backend = "plotly"
import numpy as np
from ipywidgets import interact, widgets
from pathlib import Path

p = Path.home()
p = p/'OneDrive'/'Documentos'/'Python'/'Results'/'CSV'/'DRX_EG'

# %%
filenames = ['500_1h.csv', '1000.csv','1000_1h.csv']
frames = dict()
for filename in filenames:
        filepath = p/filename
        try:
            frames[filepath.name] = pd.read_csv(filepath,
                                                delim_whitespace=True,
                                                skiprows=32,
                                                names=['2Theta','I'])
            frames[filepath.name]['I_norm'] = frames[filepath.name]['I']/frames[filepath.name]['I'].max()
        except FileNotFoundError:
            pass

# %%
interact(lambda key: px.line(frames[key],x = '2Theta', y='I_norm'),
         key = list(frames.keys())
        )
# Out:
# interactive(children=(Dropdown(description='key', options=('500_1h.csv', '1000.csv', '1000_1h.csv'), value='50…
# <function __main__.<lambda>(key)>

# %%
interact(lambda key:frames[key],
         key = list(frames.keys())
        )
# Out:
# interactive(children=(Dropdown(description='key', options=('500_1h.csv', '1000.csv', '1000_1h.csv'), value='50…
# <function __main__.<lambda>(key)>

# %%
name = {'500_1h.csv': 'NPG (500°C)', '1000_1h.csv':'NPG (1000°C)', '1000.csv':'EG (1000°C)'}
fig = go.Figure()
for key, entry in frames.items():
    fig.add_trace(go.Scatter(x = entry['2Theta'], y=entry['I_norm'],name = name[key], mode='lines'))

# %%
fig.update_layout(xaxis_title_text = 'Ângulo de incidência (2θ, °)',
                  yaxis_title_text = 'Intensidade relativa',
                  yaxis_tickformat = '%',
                  
                 )
# Out:
# <div>
#
#
#             <div id="71387dc7-fc3f-43da-80ac-7e3265f406bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("71387dc7-fc3f-43da-80ac-7e3265f406bf")) {
#                     Plotly.newPlot(
#                         '71387dc7-fc3f-43da-80ac-7e3265f406bf',
#                         [{"mode": "lines", "name": "NPG (500\u00b0C)", "type": "scatter", "x": [10.02, 10.04, 10.06, 10.08, 10.1, 10.12, 10.14, 10.16, 10.18, 10.2, 10.22, 10.24, 10.26, 10.28, 10.3, 10.32, 10.34, 10.36, 10.38, 10.4, 10.42, 10.44, 10.46, 10.48, 10.5, 10.52, 10.54, 10.56, 10.58, 10.6, 10.62, 10.64, 10.66, 10.68, 10.7, 10.72, 10.74, 10.76, 10.78, 10.8, 10.82, 10.84, 10.86, 10.88, 10.9, 10.92, 10.94, 10.96, 10.98, 11.0, 11.02, 11.04, 11.06, 11.08, 11.1, 11.12, 11.14, 11.16, 11.18, 11.2, 11.22, 11.24, 11.26, 11.28, 11.3, 11.32, 11.34, 11.36, 11.38, 11.4, 11.42, 11.44, 11.46, 11.48, 11.5, 11.52, 11.54, 11.56, 11.58, 11.6, 11.62, 11.64, 11.66, 11.68, 11.7, 11.72, 11.74, 11.76, 11.78, 11.8, 11.82, 11.84, 11.86, 11.88, 11.9, 11.92, 11.94, 11.96, 11.98, 12.0, 12.02, 12.04, 12.06, 12.08, 12.1, 12.12, 12.14, 12.16, 12.18, 12.2, 12.22, 12.24, 12.26, 12.28, 12.3, 12.32, 12.34, 12.36, 12.38, 12.4, 12.
, 18.64, 18.66, 18.68, 18.7, 18.72, 18.74, 18.76, 18.78, 18.8, 18.82, 18.84, 18.86, 18.88, 18.9, 18.92, 18.94, 18.96, 18.98, 19.0, 19.02, 19.04, 19.06, 19.08, 19.1, 19.12, 19.14, 19.16, 19.18, 19.2, 19.22, 19.24, 19.26, 19.28, 19.3, 19.32, 19.34, 19.36, 19.38, 19.4, 19.42, 19.44, 19.46, 19.48, 19.5, 19.52, 19.54, 19.56, 19.58, 19.6, 19.62, 19.64, 19.66, 19.68, 19.7, 19.72, 19.74, 19.76, 19.78, 19.8, 19.82, 19.84, 19.86, 19.88, 19.9, 19.92, 19.94, 19.96, 19.98, 20.0, 20.02, 20.04, 20.06, 20.08, 20.1, 20.12, 20.14, 20.16, 20.18, 20.2, 20.22, 20.24, 20.26, 20.28, 20.3, 20.32, 20.34, 20.36, 20.38, 20.4, 20.42, 20.44, 20.46, 20.48, 20.5, 20.52, 20.54, 20.56, 20.58, 20.6, 20.62, 20.64, 20.66, 20.68, 20.7, 20.72, 20.74, 20.76, 20.78, 20.8, 20.82, 20.84, 20.86, 20.88, 20.9, 20.92, 20.94, 20.96, 20.98, 21.0, 21.02, 21.04, 21.06, 21.08, 21.1, 21.12, 21.14, 21.16, 21.18, 21.2, 21.22, 21.24, 21.26, 21.28, 21.3, 21.32, 21.34, 21.36, 21.38, 21.4, 21.42, 21.44, 21.46, 21.48,  ...

# %%
fig.write_html('drx1.html')

# %%
fig = go.Figure()
for key, entry in frames.items():
    if name[key]=='NPG (1000°C)':
        fig.add_trace(go.Scatter(x = entry['2Theta'], y=entry['I'],name = name[key], mode='lines'))

# %%
fig.update_layout(xaxis_title_text = 'Ângulo de incidência (2θ, °)',
                  yaxis_title_text = 'Intensidade [U.A.]'
                 )
# Out:
# <div>
#
#
#             <div id="f91ee479-7223-48d4-9617-2b4c5e1e6be3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f91ee479-7223-48d4-9617-2b4c5e1e6be3")) {
#                     Plotly.newPlot(
#                         'f91ee479-7223-48d4-9617-2b4c5e1e6be3',
#                         [{"mode": "lines", "name": "NPG (1000\u00b0C)", "type": "scatter", "x": [10.02, 10.04, 10.06, 10.08, 10.1, 10.12, 10.14, 10.16, 10.18, 10.2, 10.22, 10.24, 10.26, 10.28, 10.3, 10.32, 10.34, 10.36, 10.38, 10.4, 10.42, 10.44, 10.46, 10.48, 10.5, 10.52, 10.54, 10.56, 10.58, 10.6, 10.62, 10.64, 10.66, 10.68, 10.7, 10.72, 10.74, 10.76, 10.78, 10.8, 10.82, 10.84, 10.86, 10.88, 10.9, 10.92, 10.94, 10.96, 10.98, 11.0, 11.02, 11.04, 11.06, 11.08, 11.1, 11.12, 11.14, 11.16, 11.18, 11.2, 11.22, 11.24, 11.26, 11.28, 11.3, 11.32, 11.34, 11.36, 11.38, 11.4, 11.42, 11.44, 11.46, 11.48, 11.5, 11.52, 11.54, 11.56, 11.58, 11.6, 11.62, 11.64, 11.66, 11.68, 11.7, 11.72, 11.74, 11.76, 11.78, 11.8, 11.82, 11.84, 11.86, 11.88, 11.9, 11.92, 
.96, 17.98, 18.0, 18.02, 18.04, 18.06, 18.08, 18.1, 18.12, 18.14, 18.16, 18.18, 18.2, 18.22, 18.24, 18.26, 18.28, 18.3, 18.32, 18.34, 18.36, 18.38, 18.4, 18.42, 18.44, 18.46, 18.48, 18.5, 18.52, 18.54, 18.56, 18.58, 18.6, 18.62, 18.64, 18.66, 18.68, 18.7, 18.72, 18.74, 18.76, 18.78, 18.8, 18.82, 18.84, 18.86, 18.88, 18.9, 18.92, 18.94, 18.96, 18.98, 19.0, 19.02, 19.04, 19.06, 19.08, 19.1, 19.12, 19.14, 19.16, 19.18, 19.2, 19.22, 19.24, 19.26, 19.28, 19.3, 19.32, 19.34, 19.36, 19.38, 19.4, 19.42, 19.44, 19.46, 19.48, 19.5, 19.52, 19.54, 19.56, 19.58, 19.6, 19.62, 19.64, 19.66, 19.68, 19.7, 19.72, 19.74, 19.76, 19.78, 19.8, 19.82, 19.84, 19.86, 19.88, 19.9, 19.92, 19.94, 19.96, 19.98, 20.0, 20.02, 20.04, 20.06, 20.08, 20.1, 20.12, 20.14, 20.16, 20.18, 20.2, 20.22, 20.24, 20.26, 20.28, 20.3, 20.32, 20.34, 20.36, 20.38, 20.4, 20.42, 20.44, 20.46, 20.48, 20.5, 20.52, 20.54, 20.56, 20.58, 20.6, 20.62, 20.64, 20.66, 20.68, 20.7, 20.72, 20.74, 20.76, 20.78, 20.8, 20.82, 20.84, 20.86, 20.88, 20.9, 20.92, 20.94, 20.96, 20.98, 21.0, 21.02, 21.04, 21.06, 21.08, 21.1, 21.12, 21.14, 21.16, 21.18, 21.2, 21.22, 21.24, 21.26, 21.28, 21.3, 21.32, 21.34, 21.36, 21.38, 21.4, 21.42, 21.44, 21.46, 21.48, ...

# %%
df = frames['500_1h.csv']
df['Kind']='Nanoplaquetas (500°C)'
dfe = frames['1000.csv']
dfe['Kind']='Expandido (1000°C)'
dfn = frames['1000_1h.csv']
dfn['Kind']='Nanoplaquetas (1000°C)'

# %%
df = df.merge(dfe, how='outer')
df = df.merge(dfn, how='outer')

# %%
fig = px.line_3d(df, y = '2Theta', z = 'I_norm', x = 'Kind', color='Kind')

# %%
fig.update_layout(
                  scene_xaxis_visible = False,
                  scene_yaxis_title_text = 'Ângulo de incidência (2θ, °)',
                  scene_zaxis_title_text = 'Intensidade relativa',
                  legend_title_text = 'Tipo',
                  scene_yaxis_showgrid = True,
                  scene_zaxis_showgrid = False,
                  scene_zaxis_showticklabels = False,
                  scene_yaxis_showbackground = False,
                  scene_zaxis_showbackground = True,
                 )
# Out:
# <div>
#
#
#             <div id="1afddebf-1a45-4d43-a7a3-f16c98c20b38" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1afddebf-1a45-4d43-a7a3-f16c98c20b38")) {
#                     Plotly.newPlot(
#                         '1afddebf-1a45-4d43-a7a3-f16c98c20b38',
#                         [{"hovertemplate": "Kind=%{x}<br>2Theta=%{y}<br>I_norm=%{z}<extra></extra>", "legendgroup": "Nanoplaquetas (500\u00b0C)", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Nanoplaquetas (500\u00b0C)", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": ["Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C)", "Nanoplaquetas (500\u00b0C) ...

# %%
fig.write_html('drx2.html')

# %% [markdown]
# ## Cálculo da distância interplanar do grafite
#
# ### Lei de Bragg:
#
# $$2d\sin{\theta} = n\lambda \therefore d = \frac{n\lambda}{2\sin{\theta}}$$
#
# Com $n = 1$, $\lambda = Cu_{K-\alpha} = 1,5406 Å$, $\lambda_{grafite}=26,66°$ e $\lambda_{NPG}=26,4°$

# %%
Kalpha = 1.541838
d = (1/2)*Kalpha/np.sin(26.4*np.pi/360)

# %%
d/10
# Out:
# 0.3376028300774257

# %% [markdown]
# ### Nanoplaquetas de grafite:
#
# Distância interplanar
#
# $$ d_{NPG} = 0,338 (nm) $$

# %%
d = (1/2)*Kalpha/np.sin(26.66*np.pi/360)

# %%
d/10
# Out:
# 0.3343691322582159

# %% [markdown]
# ### Grafite natural:
#
# Distância interplanar
#
# $$ d_{grafite} = 0,334 (nm) $$

# %% [markdown]
# ## Tamanho de grão cristalino

# %%
def interpolate (x, x1, x2, y1, y2):
    y = y1+((y2-y1)*(x-x1)/(x2-x1))
    return y

# %%
a = interpolate(.5, df.at[3831,'I_norm'], df.at[3830,'I_norm'], df.at[3830,'2Theta'], df.at[3831,'2Theta'])

b = interpolate(.5, df.at[3800,'I_norm'], df.at[3801,'I_norm'], df.at[3800,'2Theta'], df.at[3801,'2Theta'])

a-b
# Out:
# 0.6018909592822652

# %%
a = interpolate(.5, df.at[2331,'I_norm'], df.at[2330,'I_norm'], df.at[2330,'2Theta'], df.at[2331,'2Theta'])

b = interpolate(.5, df.at[2298,'I_norm'], df.at[2299,'I_norm'], df.at[2298,'2Theta'], df.at[2299,'2Theta'])

a-b
# Out:
# 0.6317762128325519

# %%
df[df['I_norm']==1]
# Out:
#       2Theta      I  I_norm                    Kind
# 824     26.5  19386     1.0   Nanoplaquetas (500°C)
# 2314    26.3   1600     1.0      Expandido (1000°C)
# 3819    26.4   5764     1.0  Nanoplaquetas (1000°C)

# %% [markdown]
# ### Largura em meia altura
#
# $$ FWHM_{NPG} = 0,602 ° $$
# ou
# $$ FWHM_{NPG} = 0,5656 ° $$
# (método de ajuste de curva gaussiana)
#
# $$ FWHM_{EG} = 0,632 ° $$
# ou
# $$ FWHM_{EG} = 0,614 ° $$
# (método de ajuste de curva gaussiana)
#
# #### Debye-Scherrer:
#
# O tamanho de grão cristalino (L) é inversamente proporcional a largura em meia altura (FWHM)
#
# $$ L = \frac{K\lambda}{FWHM.\cos{\theta}} $$
# com $\lambda = 0.15406 nm$ e $K = 1$

# %%
Lnpg = .15406/(0.602*(np.pi/180)*np.cos((26.5/2)*(np.pi/180)))

# %%
Lnpg
# Out:
# 15.063779396162335

# %%
Lnpg = .15406/(0.5656*(np.pi/180)*np.cos((26.5/2)*(np.pi/180)))

# %%
Lnpg
# Out:
# 16.033230545420306

# %% [markdown]
# $$15,06nm > L_{NPG} > 16,03 nm $$

# %%
Leg = .15406/(0.614*(np.pi/180)*np.cos((26.3/2)*(np.pi/180)))

# %%
Leg
# Out:
# 14.763328480815266

# %% [markdown]
# $$14,34nm > L_{EG} > 14,76 nm $$
