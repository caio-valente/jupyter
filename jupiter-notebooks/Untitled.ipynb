# %%
import numpy as np

import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns= ['Alpha', 'Beta', 'Gamma', 'Delta'])
df
# Out:
#                Alpha      Beta     Gamma     Delta
# 2013-01-01 -1.857998 -2.645904  0.480650 -1.172024
# 2013-01-02  0.684695 -1.922545  1.115875  0.559561
# 2013-01-03  2.057311  0.917615 -1.720089  0.159516
# 2013-01-04  2.059951  1.147141  0.297729 -2.670578
# 2013-01-05  0.078140  0.423611  0.638493  0.652218
# 2013-01-06 -0.639035 -1.079430  0.162930  0.104021

# %%
df.sort_values(by='Alpha')
# Out:
#                Alpha      Beta     Gamma     Delta
# 2013-01-01 -1.857998 -2.645904  0.480650 -1.172024
# 2013-01-06 -0.639035 -1.079430  0.162930  0.104021
# 2013-01-05  0.078140  0.423611  0.638493  0.652218
# 2013-01-02  0.684695 -1.922545  1.115875  0.559561
# 2013-01-03  2.057311  0.917615 -1.720089  0.159516
# 2013-01-04  2.059951  1.147141  0.297729 -2.670578

# %%
data_007 = pd.read_csv('Downloads\PU_fatorial_007.csv', header = [17,18],
                       dtype = {'Fx': np.float64, 'Fz': np.float64, 'COF': np.float64})

# %%
import matplotlib.pyplot as plt

# %%
data_007
# Out:
#                  T     Fx     Fz     AE     LV       Z      X     V1     V3  \
#                sec      N      N   Volt     mm      mm     mm mm/sec mm/sec
# 0           0.0000 -0.028 -2.603  0.907  4.499 -0.2685 -6.373 -0.018    0.0
# 1           0.0010 -0.058 -2.628  0.909  4.224 -0.2685 -6.373 -0.018    0.0
# 2           0.0020 -0.077 -2.652  0.908  4.181 -0.2690 -6.373 -0.018    0.0
# 3           0.0030 -0.090 -2.676  0.906  4.249 -0.2690 -6.373 -0.018    0.0
# 4           0.0040 -0.099 -2.707  0.908  4.370 -0.2690 -6.373 -0.018    0.0
# ...            ...    ...    ...    ...    ...     ...    ...    ...    ...
# 1078044  1078.0439  1.036 -2.505  0.914  4.651 -0.0160 -6.373  0.000    0.0
# 1078045  1078.0450  1.036 -2.530  0.914  4.793 -0.0160 -6.373  0.000    0.0
# 1078046  1078.0460  1.007 -2.556  0.917  4.925 -0.0160 -6.373  0.000    0.0
# 1078047  1078.0470  1.028 -2.522  0.919  4.993 -0.0160 -6.373  0.000    0.0
# ...

# %%
del data_007['AE']
del data_007['LV']
del data_007['X']
del data_007['V1']
del data_007['V3']
del data_007['Ff']

# %%
data_007
# Out:
#             Fx     Fz       Z                 COF
#              N      N      mm Unnamed: 10_level_1
# 0       -0.028 -2.603 -0.2685               0.011
# 1       -0.058 -2.628 -0.2685               0.022
# 2       -0.077 -2.652 -0.2690               0.029
# 3       -0.090 -2.676 -0.2690               0.034
# 4       -0.099 -2.707 -0.2690               0.037
# ...        ...    ...     ...                 ...
# 1078044  1.036 -2.505 -0.0160               0.414
# 1078045  1.036 -2.530 -0.0160               0.409
# 1078046  1.007 -2.556 -0.0160               0.394
# 1078047  1.028 -2.522 -0.0160               0.408
# 1078048  1.081 -2.464 -0.0160               0.439
#
# [1078049 rows x 4 columns]

# %%
data_007['COF']
# Out:
#          Unnamed: 10_level_1
# 0                      0.011
# 1                      0.022
# 2                      0.029
# 3                      0.034
# 4                      0.037
# ...                      ...
# 1078044                0.414
# 1078045                0.409
# 1078046                0.394
# 1078047                0.408
# 1078048                0.439
#
# [1078049 rows x 1 columns]

# %%
data_007.describe()
# Out:
#                   T            Fx            Fz             Z  \
#                 sec             N             N            mm
# count  1.078049e+06  1.078049e+06  1.078049e+06  1.078049e+06
# mean   5.390240e+02  3.050801e-02 -2.492238e+00 -1.822952e-02
# std    3.112061e+02  9.097524e-01  5.826989e-02  5.215904e-03
# min    0.000000e+00 -1.358000e+00 -2.729000e+00 -2.695000e-01
# 25%    2.695120e+02 -8.740000e-01 -2.533000e+00 -2.250000e-02
# 50%    5.390240e+02 -4.300000e-02 -2.492000e+00 -1.800000e-02
# 75%    8.085360e+02  9.400000e-01 -2.450000e+00 -1.400000e-02
# max    1.078048e+03  1.400000e+00 -2.323000e+00 -1.000000e-03
#
#                       COF
#       Unnamed: 10_level_1
# count        1.078049e+06
# mean         3.587651e-01
# std          7.011040e-02
# min          0.000000e+00
# 25%          3.220000e-01
# 50%          3.630000e-01
# 75%          3.990000e-01
# max          5.790000e-01

# %%
cof_s = data_007['COF']

# %%
data_007.plot()

# %%
data_007.plot()

# %%
data_007.at[]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-4b049d6f1ef9> in <module>
# ----> 1 data_007.at[1,1]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2197                 raise ValueError("Invalid call for scalar access (getting)!")
#    2198
# -> 2199         key = self._convert_key(key)
#    2200         return self.obj._get_value(*key, takeable=self._takeable)
#    2201
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_key(self, key, is_setter)
#    2284                 if is_integer(i) and not ax.holds_integer():
#    2285                     raise ValueError(
# -> 2286                         "At based indexing on an non-integer "
#    2287                         "index can only have non-integer "
#    2288                         "indexers"
#
# ...
