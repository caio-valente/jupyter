# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
sns.set()

# %% [markdown]
# ## PU / 2.5N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PU\PV_Limite_001.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PU / 2.5N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PU\PV_Limite_002.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PU / 5N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PU\PV_Limite_003.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PU / 5N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PU\PV_Limite_004.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PU / 8N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PU\PV_Limite_005.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PU / 8N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PU\PV_Limite_006.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PU / 2.5N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PU\PV_Limite_007.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PU / 2.5N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PU\PV_Limite_008.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PU / 5N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PU\PV_Limite_009.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PU / 5N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PU\PV_Limite_010.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PU / 8N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PU\PV_Limite_011.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PU / 8N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PU\PV_Limite_012.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG1 / 8N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG1\PV_Limite_001.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG1 / 5N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG1\PV_Limite_002.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG1 / 5N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG1\PV_Limite_003.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG1 / 2.5N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG1\PV_Limite_004.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG1 / 2.5N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG1\PV_Limite_005.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG1 / 8N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG1\PV_Limite_006.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG1 / 8N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG1\PV_Limite_007.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG1 / 5N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG1\PV_Limite_008.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG1 / 2.5N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG1\PV_Limite_009.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG1 / 5N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG1\PV_Limite_010.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG1 / 2.5N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG1\PV_Limite_011.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG1 / 8N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG1\PV_Limite_012.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG2 / 5N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG2\PV_Limite_001.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG2 / 5N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG2\PV_Limite_002.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG2 / 2.5N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG2\PV_Limite_003.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG2 / 2.5N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG2\PV_Limite_004.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG2 / 8N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG2\PV_Limite_005.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG2 / 8N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG2\PV_Limite_006.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG2 / 5N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG2\PV_Limite_007.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG2 / 8N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG2\PV_Limite_008.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG2 / 2.5N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG2\PV_Limite_009.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG2 / 2.5N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG2\PV_Limite_010.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG2 / 5N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG2\PV_Limite_011.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG2 / 8N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG2\PV_Limite_012.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG4 / 2.5N /  2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG4\PV_Limite_001.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG4 / 2.5N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG4\PV_Limite_002.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG4 / 5N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG4\PV_Limite_003.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG4 / 2.5 N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG4\PV_Limite_004.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG4 / 5.17 N / 3Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG4\PV_Limite_005.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG4 / 5.17N / 3Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG4\PV_Limite_006.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG4 / 8N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG4\PV_Limite_007.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG4 / 8N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG4\PV_Limite_008.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG4 / 8N / 2 Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG4\PV_Limite_009.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG4 / 5.17N / 3Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG4\PV_Limite_010.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG4 / 5N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG4\PV_Limite_011.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG4 / 8N / 4Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG4\PV_Limite_012.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG4 / 2.5N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG4\PV_Limite_013.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG4 / 5N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG4\PV_Limite_014.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG4 / 5N / 2Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG4\PV_Limite_015.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')

# %% [markdown]
# ## PUEG4 / 5.17N / 3Hz

# %%
filename = r'C:\Users\Caiot\OneDrive\Documentos\Python\Results\CSV\PUEG4\PV_Limite_016.csv'
df = pd.read_csv(filename, header = 17, skiprows = [21])

df[(df['T']>705)&(df['T']<706)].plot(kind = 'line', x = 'T', y='COF')

df['T_r']= df['T'].round(0)

sns.relplot(data = df, x = 'T_r', y = 'COF', kind='line')
